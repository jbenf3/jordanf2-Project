# %%
# this program will track tennis statistics and return a graphical representation of the tennis statistics on a tennis court
# inputs:
    # first serve (in or out)
    # if first serve out, second serve (in or out)
    
import math
import #other stuff

def displayServeOptions:
    # first serve in
    num_first_serves_in += 1
    total_first_serves += 1
    # first serve out
    total_first_serves += 1
    # ace
    num_aces += 1
    num_first_serves_in += 1
    total_first_serves += 1
    if (first_serve_out):
        # second serve in
        num_second_serves_in += 1
        total_second_serves += 1
        # second serve out
        total_second_serves += 1
        # ace
        num_aces += 1
        num_second_serves_in += 1
        total_second_serves += 1
        
def displayRallyOptions:
    while true:
        # fh: unf. error, forced error, winner
        # bh: unf. error, forced error, winner
        # app. shot: unf. error, forced error, winner
        # volley: unf. error, forced error, winner
        # overhead: unf. error, winner
        # lob: unf. error, forced error, winner
        
def chooseMatchFormat:
    # 1 set
    # 2 out of 3 sets
    # 3 out of 5 sets
    # 8 game pro set
    # 6 game pro set
    chooseScoreFormat:
        # ad
        # no-ad
        
def main:
    chooseMatchFormat
    
    displayServeOptions
    if (first_serve_in):
        displayRallyOptions
        if (shot_missed):
            opponent_score += 1
        else:
            own_score += 1
